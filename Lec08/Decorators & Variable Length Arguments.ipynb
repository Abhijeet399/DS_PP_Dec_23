# %%
print(1, 2, 3, 4, 5)
# Out:
# 1 2 3 4 5

# %%
def adder(a, b, c = 0):
    print(a + b + c)

# %%
adder(3,2,1)
# Out:
# 6

# %%
def adder(a, b, *abhijeet, **xyz):
    result = 0
    result = a + b
    for i in abhijeet:
        result += i
    print(result)
    print(abhijeet)
    print(xyz)
    for i in xyz:
        print(xyz[i])
        result+=xyz[i]
    print(result)

# %%
adder(1, 2, 3, 4, name = 2, func = 100)
# Out:
# 10
# (3, 4)
# {'name': 2, 'func': 100}
# 2
# 100
# 112

# %%
# Decorators

# %%
users = {
    'Abhijeet': 'password', 
    'xyz': '12345678'
}

# %%
users['Abhijeet']
# Out:
# 'password'

# %%
def adder(a, b):
    print(a + b)

# %%
name = 'Abhijeet'
password = 'password'
if name in users and users[name] == password:
    print('Authenticated')
    adder(1, 25)
# Out:
# Authenticated
# 26

# %%
for i in users:
    print(i)
# Out:
# Abhijeet
# xyz

# %%
def adder(a, b):
    print(a + b)

# %%
def login_requ(abc):
    
    def wrapper(username, password, *args):
        if username in users and users[username] == password:
            print('Authenticated')
            abc(*args)
        else:
            print('Try again')
    
    return wrapper

# %%
prot_add = login_requ(adder)

# %%
print(prot_add)
# Out:
# <function login_requ.<locals>.wrapper at 0x0000020BFA4520D0>

# %%
prot_add('Abhijeet', 'password', 1, 2)
# Out:
# Authenticated
# 3

# %%
adder(1, 2)
# Out:
# 3

# %%
adder = login_requ(adder)

# %%
adder('Abc', 'PQr', 1, 2)
# Out:
# Try again

# %%
adder('Abhijeet', 'password', 1, 2)
# Out:
# Authenticated
# 3

# %%
def adder(a, b):
    print(a + b)

# %%
def login_requ(abc):
    
    def wrapper(username, password, *args):
        if username in users and users[username] == password:
            print('Authenticated')
            abc(*args)
        else:
            print('Try again')
    
    return wrapper

# %%
adder = login_requ(adder)

# %%
print(adder)
# Out:
# <function login_requ.<locals>.wrapper at 0x0000020BFA452940>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def cal(a, b):
    return a+b, a-b, a*b, a/b

# %%
a, b, c, d = cal(1,2)

# %%
print(a, b, c, d)
# Out:
# 3 -1 2 0.5
